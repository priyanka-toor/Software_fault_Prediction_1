# %%
import pandas as pd
data=pd.read_csv('fmea.csv')

# %%
data.head(84)
# Out:
#    Unnamed: 0             Unnamed: 1       MNB       BNB       GNB       DTC  \
# 0         ALM                  black  0.341880  0.054795  0.547771  0.384615
# 1         NaN                 celery  0.000000  0.461773  0.367868  0.338677
# 2         NaN               C python  0.764651  0.765471  0.743732  0.679426
# 3         NaN  django-rest-framework  0.811060  0.803101  0.742754  0.760563
# 4         NaN                    jax  0.760697  0.781651  0.790378  0.752809
# ..        ...                    ...       ...       ...       ...       ...
# 79        NaN                 radash  0.000000  0.000000  0.173913  0.280543
# 80        NaN                 scrapy  0.914676  1.000000  1.000000  1.000000
# 81        NaN                  spaCy  0.827373  1.000000  1.000000  1.000000
# 82        NaN           transformers  0.000000  0.000000  0.350975  0.383292
# 83        NaN                 yolov5  0.787313  0.786181  0.746747  0.765358
#
# ...
